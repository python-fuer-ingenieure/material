# %% [markdown]
# # Grundlagen
#
# Dieses Jupyter-Notebook enthält den Quelltext für Kapitel 3 »Grundlagen« im Buch [Python für Ingenieure für Dummies](https://python-fuer-ingenieure.de/).

# %% [markdown]
# ### Zahlen

# %% [markdown]
# `begin calculator`

# %%
# Kommentare beginnen mit # und werden vom Interpreter ignoriert
# Grundrechenarten funktionieren wie erwartet
100 + 1
# Out:
# 101

# %%
# Punkt- geht vor Strichrechnung
2+3*4
# Out:
# 14

# %%
(2+3)*4
# Out:
# 20

# %%
# Mit Division verlassen wir die natürlichen Zahlen
3/2
# Out:
# 1.5

# %%
4/2  # Division liefert immer eine Gleitkommazahl
# Out:
# 2.0

# %%
# Potenzen mit **
2**10
# Out:
# 1024

# %%
1.024e3  # Kurzschreibweise für Zehnerpotenzen
# Out:
# 1024.0

# %% [markdown]
# `end`

# %% [markdown]
# `begin number_types`

# %%
type(32)
# Out:
# int

# %%
type(32.5)
# Out:
# float

# %% [markdown]
# `end`

# %% [markdown]
# `begin assignment`

# %%
x = 7 # Variable anlegen und zuweisen mit =
1/x + x
# Out:
# 7.142857142857143

# %%
x += 1  # entspricht x = x + 1
x
# Out:
# 8

# %%
x *= 2  # x = x * 2
x
# Out:
# 16

# %% [markdown]
# `end`

# %% [markdown]
# `begin unlimited`

# %%
2**2000
print("1148130695274254524232833201177681984022317702088695...376") #!
# Out:
# 1148130695274254524232833201177681984022317702088695...376

# %%
#!2.0**2000
print("OverflowError: (34, 'Result too large')")#!
# Out:
# OverflowError: (34, 'Result too large')

# %% [markdown]
# `end`

# %% [markdown]
# # Booleans

# %% [markdown]
# `begin bool_literal`

# %%
a_bool = True
another_bool = False
type(a_bool)
# Out:
# bool

# %% [markdown]
# `end`

# %% [markdown]
# `begin bool_comparisons`

# %%
3.14 < 3
# Out:
# False

# %%
-1/12 >= 0
# Out:
# False

# %%
6 * 69 == 420  # Gleich
# Out:
# False

# %%
0.33333333333333 != 1/3  # Ungleich
# Out:
# True

# %%
x = 12
# Vergleichsoperatoren können verkettet werden
10 <= x < 20
# Out:
# True

# %%
# Achtung: Unterschied Zuweisung = und Vergleich ==
is_eight = x == 8
print(is_eight)
# Out:
# False

# %% [markdown]
# `end`

# %% [markdown]
# `begin bool_operations`

# %%
# Einige Annahmen über Sie
is_engineer = True
needs_to_program = False
wants_to_program = True
afraid_of_snakes = False
# Könnte Sie dieses Buch interessieren?
# Lange Zeilen werden mit Backslash \ umgebrochen
potential_reader = is_engineer and \
                  (needs_to_program or wants_to_program) and \
                   not afraid_of_snakes
print(potential_reader)
# Out:
# True

# %%
# Wahrheitsverknüpfungen haben die allerniedrigste Präzedenz,
# d. h., was links und rechts steht, wird zuerst ausgewertet
# --> spart Klammern
x = 42
x > 10 or x < -10
# Out:
# True

# %% [markdown]
# `end`

# %% [markdown]
# # Typen

# %% [markdown]
# `begin number_constructor`

# %%
int(42)  # Erstellt ein int mit Wert 42
# Out:
# 42

# %%
int(42.5) # Konvertiert float zu int
# Out:
# 42

# %%
float(42)
# Out:
# 42.0

# %%
bool(1)  # 0 entspricht False, alles andere True
# Out:
# True

# %% [markdown]
# `end`

# %% [markdown]
# `begin datetime_constructor`

# %%
# Kalenderfunktionen liegen in separatem "Modul" und
# müssen importiert werden
from datetime import datetime
sw = datetime(1977, 5, 25, 19, 0)

# %% [markdown]
# `end`

# %% [markdown]
# `begin datetime_attributes`

# %%
sw.year
# Out:
# 1977

# %%
sw.hour
# Out:
# 19

# %% [markdown]
# `end`

# %% [markdown]
# `begin datetime_methods`

# %%
sw.weekday()  # Berechne Wochentag (Mittwoch)
# Out:
# 2

# %%
# Gib datetime als Text in spezifiziertem Format aus
sw.strftime("%A, %m. %B %Y, %H:%M")
# Out:
# 'Wednesday, 05. May 1977, 19:00'

# %% [markdown]
# `end`

# %% [markdown]
# `begin obj_eq`

# %%
date2 = datetime(1977, 5, 25, 19, 0)

# %%
sw == date2  # Objekte sind inhaltlich gleich
# Out:
# True

# %%
sw is date2  # Identitäten (Speicherstellen) sind unterschiedlich
# Out:
# False

# %% [markdown]
# `end`

# %% [markdown]
# # Listen

# %% [markdown]
# `begin list_def`

# %%
# Listenelemente in [] schreiben und mit Kommata trennen
numbers = [1, 2, 789, 4]
# Listen können beliebige Typen enthalten
booleans = [True, False, False, True]
# Auch gemischt und geschachtelt
# Achtung: Davon ist meistens abzuraten
chaos = [3.14, True, 4, [1, 2, 3], False]

# %% [markdown]
# `end list_def`

# %% [markdown]
# `begin list_read`

# %%
numbers[2]
# Out:
# 789

# %%
chaos[3][1]
# Out:
# 2

# %%
# Negative Indizes zählen von hinten
numbers[-1]
# Out:
# 4

# %%
# Listenindizes werden auf Intervall geprüft
# Fehler, denn numbers hat nur 4 Elemente (Indizes 0 bis 3)
#!numbers[4]
print("IndexError: list index out of range")#!
# Out:
# IndexError: list index out of range

# %% [markdown]
# `end`

# %% [markdown]
# `begin list_write`

# %%
numbers[2] = 3
numbers
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# `end`

# %% [markdown]
# `begin list_trap`

# %%
a = [1, 2, 3]
# b verweist auf die selbe Liste wie a
b = a
# Ändere ersten Eintrag
b[0] = 7
b # ist erwartungsgemäß anders
# Out:
# [7, 2, 3]

# %%
a # ist die gleiche Listeninstanz und damit auch verändert
# Out:
# [7, 2, 3]

# %% [markdown]
# `end`

# %% [markdown]
# `begin list_copy`

# %%
# Funktion list(...) mit Liste als Argument kopiert diese
c = list(a)
c[2] = 99  # Ändere letztes Argument
c
# Out:
# [7, 2, 99]

# %%
a  # ist unverändert
# Out:
# [7, 2, 3]

# %% [markdown]
# `end`

# %% [markdown]
# `begin list_slices`

# %%
fib = [0, 1, 1, 2, 3, 5, 8, 13]
# Teilliste von 0 (inkl.) bis 4 (exkl.)!
# Indizes sind also 0, 1, 2, 3
fib[0:4]
# Out:
# [0, 1, 1, 2]

# %%
# Obere und untere Grenze können ausgelassen werden
fib[:4]
# Out:
# [0, 1, 1, 2]

# %%
fib[4:]
# Out:
# [3, 5, 8, 13]

# %%
# Alles außer erstes und letztes Element
fib[1:-1]
# Out:
# [1, 1, 2, 3, 5, 8]

# %%
# Schrittweite angeben mit [start:stop:step]
fib[0:7:2]
# Out:
# [0, 1, 3, 8]

# %%
# Auslassen geht natürlich immer noch
fib[::-1]
# Out:
# [13, 8, 5, 3, 2, 1, 1, 0]

# %%
# Slicing funktioniert auch auf linker Seite einer Zuweisung
fib[4:] = fib[:4]
fib
# Out:
# [0, 1, 1, 2, 0, 1, 1, 2]

# %% [markdown]
# `end`

# %% [markdown]
# `begin list_more`

# %%
a = [5, 6, 7, 8, 9]
a + [10, 11, 12]  # Zwei Listen aneinanderfügen
# Out:
# [5, 6, 7, 8, 9, 10, 11, 12]

# %%
len(a)  # Länge einer Liste
# Out:
# 5

# %%
7 in a  # Ist Element in Liste enthalten?
# Out:
# True

# %%
del a[3]  # Element mit Index entfernen (kann auch Slices)
a
# Out:
# [5, 6, 7, 9]

# %%
a.pop(2)  # Element mit Index entfernen und zurückgeben
# Out:
# 7

# %%
a
# Out:
# [5, 6, 9]

# %%
a.remove(5)  # Element mit bestimmtem Wert entfernen
a
# Out:
# [6, 9]

# %%
a.append(10)  # Element an Ende anhängen
a
# Out:
# [6, 9, 10]

# %%
a.insert(1, 7)  # Element an Index einfügen
a
# Out:
# [6, 7, 9, 10]

# %% [markdown]
# `end`

# %% [markdown]
# `begin str_def_old`

# %%
doppelt = "Ich bin ein String."
einfach = 'Ich auch!'

# %%
# Strings sind mit UTF-8 codiert und unterstützen Unicode
titel = "🐍 für 🛠"

# %% [markdown]
# `end`

# %% [markdown]
# `begin str_def`

# %%
doppelt = "Ich bin ein String."
einfach = 'Ich auch!'

# %% [markdown]
# `end`

# %% [markdown]
# `begin str_ops`

# %%
doppelt + " " + einfach  # Zusammenfügen mit +
# Out:
# 'Ich bin ein String. Ich auch!'

# %%
einfach[0]
# Out:
# 'I'

# %%
einfach[::-1]
# Out:
# '!hcua hcI'

# %% [markdown]
# `end`

# %% [markdown]
# `begin print`

# %%
print("Hallo Python!")
# Out:
# Hallo Python!

# %%
print("Wie darf ich Sie nennen?")
#!name = input()
#!print("Herzlich Willkommen, " + name + "!")
print("Daniel Düsentrieb") #!
print("Herzlich Willkommen, Daniel Düsentrieb!") #!
# Out:
# Wie darf ich Sie nennen?
# Daniel Düsentrieb
# Herzlich Willkommen, Daniel Düsentrieb!

# %% [markdown]
# `end`

# %% [markdown]
# `begin fstrings`

# %%
x = 905
f"Sie haben {x} ungelesene E-Mails!"
# Out:
# 'Sie haben 905 ungelesene E-Mails!'

# %% [markdown]
# `end`

# %%
type((1, 2))
# Out:
# tuple

# %% [markdown]
# `begin tuple_def`

# %%
size = (1920, 1080)  # Tupel mit zwei Einträgen

# %%
# Tupel mit Elementen unterschiedlichen Typs sind sehr üblich,
# welche Werte an welcher Stelle stehen, muss man aber
# händisch dokumentieren.
var_x = ('x', 'm/s', [3, 3.1, 3.4, 3.2])

# %%
# Indizierung wie bei Listen
var_x[1]
# Out:
# 'm/s'

# %%
# Einige Listenfunktionen gehen auch, solange sie die
# Größe und den Inhalt nicht verändern
len(var_x)
# Out:
# 3

# %% [markdown]
# `end`

# %% [markdown]
# `begin tuple_destruct`

# %%
var_name, var_unit, var_values = var_x

# %%
var_unit
# Out:
# 'm/s'

# %% [markdown]
# `end`

# %% [markdown]
# `begin tuple_special`

# %%
empty_tuple = ()  # Das leere Tupel

# %%
one_tuple = (4,)  # Tupel mit einem Eintrag

# %%
four, = one_tuple  # 1-Tupel "zerlegen"
four
# Out:
# 4

# %% [markdown]
# `end`

# %% [markdown]
# `begin dict_def`

# %%
# Def. in geschweiften Klammern nach dem Schema "key: value"
dict_x = {'name': 'x', 'unit': 'm/s',
          'values': [3, 3.1, 3.4, 3.2]}
# Lesen und Schreiben jetzt über die Schlüssel
dict_x['unit']
# Out:
# 'm/s'

# %%
dict_x['values'].append(3.3)
dict_x
# Out:
# {'name': 'x', 'unit': 'm/s', 'values': [3, 3.1, 3.4, 3.2, 3.3]}

# %%
# Als Schlüssel können beliebige Konstanten dienen
wavelengths = {450: 'blau', 520: 'grün', 590: 'gelb',
               620: 'orange', 650: 'rot'}

# %% [markdown]
# `end`

# %% [markdown]
# `begin dict_more`

# %%
# Neue Elemente können jederzeit hinzugefügt werden
wavelengths[400] = 'violett'
wavelengths
# Out:
# {450: 'blau',
#  520: 'grün',
#  590: 'gelb',
#  620: 'orange',
#  650: 'rot',
#  400: 'violett'}

# %%
# Löschen wie bei Listen
del wavelengths[620]
wavelengths
# Out:
# {450: 'blau', 520: 'grün', 590: 'gelb', 650: 'rot', 400: 'violett'}

# %%
# Existenz von Schlüsseln prüfen
'name' in dict_x
# Out:
# True

# %%
len(dict_x)  # Anzahl von Einträgen
# Out:
# 3

# %%
dict_x.keys()  # Alle Schlüssel
# Out:
# dict_keys(['name', 'unit', 'values'])

# %%
dict_x.values()  # Alle Werte
# Out:
# dict_values(['x', 'm/s', [3, 3.1, 3.4, 3.2, 3.3]])

# %%
dict_x.items()  # Einträge als Tupel von Schlüssel und Wert
print("dict_items([('name', 'x'), ('unit', 'm/s'),\n            ('values', [3, 3.1, 3.4, 3.2, 3.3])])")#!
# Out:
# dict_items([('name', 'x'), ('unit', 'm/s'),
#             ('values', [3, 3.1, 3.4, 3.2, 3.3])])

# %% [markdown]
# `end`

# %% [markdown]
# `begin if_def --input_prefix=""`

# %%
#!if bedingung:
    # Führe aus, wenn "bedingung" wahr ist
#!elif alternativ_bedingung_1:
    # Führe aus, wenn vorherige Bedingung nicht zutrifft
    # und "alternativ_bedingung_1" wahr ist
#!elif alternativ_bedingung_2:
    # Führe aus, wenn vorherige Bedingungen nicht zutreffen
    # und "alternativ_bedingung_2" wahr ist
#!else:
    # Führe aus, wenn keine der vorherigen Bedingungen zutreffen

# %% [markdown]
# `end`

# %% [markdown]
# `begin if_temp`

# %%
temperatur = 20

if temperatur < 15:
    print('Zu kalt, heizen...')
elif temperatur < 25:
    print('Temperatur im Nominalbereich')
else:
    print('Zu heiß, abkühlen...')
# Out:
# Temperatur im Nominalbereich

# %% [markdown]
# `end`

# %% [markdown]
# `begin line_continuation --input_prefix=""`

# %%
# Variante 1: Impliziter Umbruch in Klammern
#!if (eine_sehr_lange_bedingung and
#!    noch_eine_sehr_lange_bedingung):
#!    ...
#_
# Variante 2: Expliziter Umbruch mit Backslash
#!if eine_sehr_lange_bedingung and \
#!   noch_eine_sehr_lange_bedingung:
#!    ...

# %% [markdown]
# `end`

# %% [markdown]
# `begin truthy_list --input_prefix=""`

# %%
#!if meine_liste:  # anstelle len(meine_liste) > 0
#!    print('Liste ist nicht leer.')

# %% [markdown]
# `end`

# %% [markdown]
# `begin while_ex`

# %%
commands = [1, 4, 3, "summe 1", 6, 1, "summe 2", "exit", 7, 8, 9]
current_sum = 0

while commands:  # Solange commands noch Elemente enthält
    c = commands.pop(0)
    
    if c == "exit":
        break  # Verlasse Schleife
    elif isinstance(c, str):
        print(c + ": " + str(current_sum))
        current_sum = 0
        continue  # Springe zum Schleifenanfang
    
    current_sum += c
# Out:
# summe 1: 8
# summe 2: 7

# %% [markdown]
# `end`

# %% [markdown]
# `begin while_new  --input_prefix=""`

# %%
# Klassische Endlosschleife
#!while True:
#!    packet = read_packet()
#!    if packet == "EXIT":
        # Ende der Kommunikation
#!        break
#!    elif packet == "NOP"
        # "No Operation", ignoriere Paket
#!        continue
#!    else:
#!        ... # Paket auswerten

# %% [markdown]
# `end`

# %% [markdown]
# `begin for_in`

# %%
measurements = [2.4, 1.7, 0.8, 1.1]
for length in measurements:
    print(length)
# Out:
# 2.4
# 1.7
# 0.8
# 1.1

# %% [markdown]
# `end`

# %% [markdown]
# `begin for_unit`

# %%
measurements = [2.4, 1.7, 0.8, 1.1]
units = ['ft', 'cm', 'm', 'ft']
unit_scales = {'m': 1, 'cm': 0.01, 'ft': 0.3048}
for i, length in enumerate(measurements):
    print(f"{i}: {length * unit_scales[units[i]]} m")
# Out:
# 0: 0.7315200000000001 m
# 1: 0.017 m
# 2: 0.8 m
# 3: 0.33528 m

# %%
#_
# Alternative: zip(a, b) gibt eine Sequenz von Tupeln, mit den
# Einträgen aus a und b paarweise kombiniert
for length, unit in zip(measurements, units):
    print(f"{length * unit_scales[unit]} m")
# Out:
# 3: 0.7315200000000001 m
# 3: 0.017 m
# 3: 0.8 m
# 3: 0.33528 m

# %% [markdown]
# `end`

# %% [markdown]
# `begin for_range`

# %%
for n in range(4):  # Iteriere von 0 (inkl.) bis 4 (exkl.)
    print(n**2)
# Out:
# 0
# 1
# 4
# 9

# %%
for n in range(10, 15):  # Start- und Stoppwert angeben
    print(n**2)
# Out:
# 100
# 121
# 144
# 169
# 196

# %% [markdown]
# `end`

# %% [markdown]
# # Funktionen

# %% [markdown]
# `begin fun_convert`

# %%
def convert_length(amount, from_unit):
    units = {'m': 1, 'cm': 1e-2, 'km': 1e3,
             'ft': 0.3048, 'in': 0.0254, 'mi': 1609.34}
    return amount * units[from_unit]

convert_length(2, 'ft')
# Out:
# 0.6096

# %% [markdown]
# `end`

# %% [markdown]
# `begin fun_optional`

# %%
def convert_length(amount, from_unit='m', to_unit='m'):
    units = {'m': 1, 'cm': 1e-2, 'km': 1e3,
             'ft': 0.3048, 'in': 0.0254, 'mi': 1609.34}
    if from_unit not in units or to_unit not in units:
        return None  # Frühzeitiger Abbruch
    
    return amount * units[from_unit] / units[to_unit]

convert_length(2, 'ft')  # 2 ft in m?
# Out:
# 0.6096

# %%
convert_length(2, 'ft', 'cm')  # 2 ft in cm?
# Out:
# 60.96

# %%
# from_unit hat Standardwert 'm',
# to_unit wird mit seinem Namen übergeben
convert_length(2, to_unit='ft')  # 2 m in ft?
# Out:
# 6.561679790026246

# %%
convert_length(2, from_unit='mi', to_unit='km')  # 2 mi in km?
# Out:
# 3.21868

# %%
# Bei benannten Argumenten ist die Reihenfolge egal
convert_length(from_unit='mi', to_unit='km', amount=2)
# Out:
# 3.21868

# %% [markdown]
# `end`

# %% [markdown]
# `begin spread_tupel`

# %%
conversion_tupel = (2, 'mi', 'km')
# Tupel "verstreichen"
convert_length(*conversion_tupel)
# Out:
# 3.21868

# %% [markdown]
# `end`

# %% [markdown]
# `begin spread_dict`

# %%
conversion_dict = {'amount': 2, 'from_unit': 'mi',
                   'to_unit': 'km'}
# Dict "verstreichen"
convert_length(**conversion_dict)
# Out:
# 3.21868

# %% [markdown]
# `end`

# %% [markdown]
# `begin fun_pass`

# %%
def design_perpetuum_mobile():
    pass

# %% [markdown]
# `end`

# %% [markdown]
# `begin fun_scoping`

# %%
y = 3
def add_y(x):
    # greift lesend auf äußere Variable y zu
    # definiert funktionsinterne Variable z
    z = x + y
    return z
#_
add_y(4)
# Out:
# 7

# %%
y = 4
# Ändert sich y, ändert sich auch das Verhalten der Funktion
add_y(4)
# Out:
# 8

# %%
# z ist außerhalb der Funktion nicht zugänglich
#!z
print("NameError: name 'z' is not defined")#!
# Out:
# NameError: name 'z' is not defined

# %% [markdown]
# `end`

# %% [markdown]
# `begin fun_docstring1 --input_prefix=""`

# %%
def quad(x=10):
    """
    Das ist ein Docstring. Typischerweise beschreibt
    er die Argumente und den Rückgabewert, z.B. so:
    
    :param x:  Zahl die quadriert wird (float, int)
    
    :returns:  Quadrat von x
    """
    
    return x**2

# %% [markdown]
# `end fun_docstring1`

# %% [markdown]
# `begin fun_docstring2`

# %%
print(quad.__doc__)
# Out:
#     Das ist ein Docstring. Typischerweise beschreibt
#     er die Argumente und den Rückgabewert, z.B. so:
#
#     :param x:  Zahl die quadriert wird (float, int)
#
#     :returns:  Quadrat von x

# %% [markdown]
# `end fun_docstring2`

# %% [markdown]
# # Imports

# %% [markdown]
# `begin import_math`

# %%
import math
math.sin(11/7)  # Eine erstaunlich gute Näherung für Pi/2
# Out:
# 0.9999998001333682

# %% [markdown]
# `end`

# %% [markdown]
# `begin import_as`

# %%
import math as m
m.sin((m.sqrt(2) + m.sqrt(3))/2) # π ≈ √2 + √3
# Out:
# 0.999997271884531

# %% [markdown]
# `end`

# %% [markdown]
# `begin import_from`

# %%
from math import sin, pi as PI
sin(PI/2)
# Out:
# 1.0

# %% [markdown]
# `end`

# %% [markdown]
# `begin import_all`

# %%
from math import *
sin(pi/2)
# Out:
# 1.0

# %% [markdown]
# `end`

# %% [markdown]
# # Fehler

# %% [markdown]
# `begin error_colon`

# %%
#!x = 7
#!if x != 0
#!    y = 1/x
#!     print(y)
print('  File "example.py", line 2\n    if x != 0\n             ^\nSyntaxError: invalid syntax') #!
# Out:
#   File "example.py", line 2
#     if x != 0
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# `end`

# %% [markdown]
# `begin error_indent`

# %%
#!x = 7
#!if x != 0:
#!    y = 1/x
#!     print(y)
print('  File "example.py", line 4\n    print(y)\n    ^\nIndentationError: unexpected indent') #!
# Out:
#   File "example.py", line 4
#     print(y)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# `end`

# %% [markdown]
# `begin error_def_sum --input_prefix=""`

# %%
def sum(xs):
    sum_result = 0
    for x in xs:
        sum_result += x
    return sum_result

def mean(xs):
    factor = 1/len(xs)  # Skalierungsfaktor 1/n
    return factor * sum(xs)

# %% [markdown]
# `end`

# %% [markdown]
# `begin error_mean --input_prefix=""`

# %%
#!mean([])
print('-----------------------------------------------------------------\nZeroDivisionError               Traceback (most recent call last)\n"app.py" in <module>\n----> 1 mean([])\n"definitions.py" in mean(xs)\n      6 \n      7 def mean(xs):\n----> 8     factor = 1/len(xs)\n      9     return factor * sum(xs)\n\nZeroDivisionError: division by zero')#!
# Out:
# -----------------------------------------------------------------
# ZeroDivisionError               Traceback (most recent call last)
# "app.py" in <module>
# ----> 1 mean([])
# "definitions.py" in mean(xs)
#       6
#       7 def mean(xs):
# ----> 8     factor = 1/len(xs)
#       9     return factor * sum(xs)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# `end`

# %%
msg = """\
-----------------------------------------------------------------
AssertionError                  Traceback (most recent call last)
<ipython-input-7-6d6b149984e1> in <module>
      1 m = 97 
----> 2 assert m % 7 == 0
      3 print(f"{m} ist durch 7 teilbar")

AssertionError: nicht durch 7 teilbar
"""

# %% [markdown]
# `begin assert1`

# %%
m = 97
#!assert m % 7 == 0, "nicht durch 7 teilbar"
#!print(f"{m} ist durch 7 teilbar")
print(msg)#!
# Out:
# -----------------------------------------------------------------
# AssertionError                  Traceback (most recent call last)
# <ipython-input-7-6d6b149984e1> in <module>
#       1 m = 97
# ----> 2 assert m % 7 == 0
#       3 print(f"{m} ist durch 7 teilbar")
#
# AssertionError: nicht durch 7 teilbar

# %% [markdown]
# `end`
